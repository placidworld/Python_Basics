# %% [markdown]
# ## Tips and Tricks to Use Jupyter Notebook

# %% [markdown]
# #### #1 - Navigate with common Shortcuts
# ##### Right click the 'Help' , click menu 'Keyboard Shortcuts', you will see a list of shortcuts.
# #### Or If you forget the shortcut, you can always go to Command Mode and press H to see the full list.
# #### Jupyter notebook also allows you to create your own shortcut if you want.
#
# #### Edit Mode (press Enter to enable)
# #### Command Mode (press Esc to enable

# %% [markdown]
# #### #2 - Show multiple Items in Output

# %%
# Jupyter notebook only shows one output at a time as shown here. 
list1 = [1, 2, 3, 4 ,5]
list2 = [22, 33]
list1
list2
# Out:
# [22, 33]

# %%
# However, you can add this code below to show all outputs in the cell.

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
list1 = [1, 2, 3, 4 ,5]
list2 = [22, 33]
list1
list2
# Out:
# [1, 2, 3, 4, 5]
# [22, 33]

# %% [markdown]
# #### #3 - Add Pictures to Jupyter notebook

# %% [markdown]
# ####  Change the cell type from Code to Markdown,
# ####  then simply drag and drop the picture into the cell.
# ####  Run the cell(Shift + Enter) to see the image

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### #4 - Execute Shell Commands Directly in Jupyter Notebook
# ##### use the exclamation point (!) at the beginning of your command

# %%
# !pip install matplotlib-venn
# Out:
# ...
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-0.11.7-py3-none-any.whl size=32155 sha256=3284615da30491c2993f40646de4054c3a2192630fcebd055453e715f471d1c9
#   Stored in directory: c:\users\heart\appdata\local\pip\cache\wheels\32\41\5f\d0f29cd092d042d8e8a87d7bbe42193166aa555ff38b377343
# Successfully built matplotlib-venn
# ...

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is A007-5CC5
#
#  Directory of C:\Users\heart\Desktop\Tutorials_Python
#
# 07/30/2022  10:35 AM    <DIR>          .
# 07/30/2022  09:01 AM    <DIR>          ..
# 07/30/2022  09:01 AM    <DIR>          .ipynb_checkpoints
# 07/30/2022  10:35 AM           506,704 Untitled.ipynb
#                1 File(s)        506,704 bytes
#                3 Dir(s)  296,792,199,168 bytes free

# %%
# If ! does not work, then use % magic commands
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#### #5 - See Built-In Magic Commands
##### Magic commands are special commands that help with productivity

# %%
# Full list of magic commands
# %lsmagic #show all magic commands
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# %matplotlib inline

# %% [markdown]
# ##### %pwd # print the current working directory
# ##### %cd # change working directory
# ##### %ls # show contents in the current directory
# ##### %load [insert Python filename here] # load code into the Jupyter notebook
# ##### %store [insert variable here] # this lets you pass  variables between Jupyter notebook
# ##### %who # use thsi to list all variables

# %%
# %who int
# Out:
# No variables match your requested type.

# %% [markdown]
# #### #6 - Measure Cell Execution Time
# ##### Use %%time to get the wall time for whole cell

# %%
# %%time
for i in range(0, 20000):
    i ** i
# Out:
# CPU times: total: 36.2 s
# Wall time: 36.3 s

# %% [markdown]
# #### #7 - Use Multicursor to Speed Up Word
# ##### Hold down the Alt key and select the entire cell content.
# ##### Press the left arrow and you will see that there are now multiple cursors
# ##### (black line in snippet below), one on each line.
# ##### From here, you can then delete all the digits in one click of the delete key.
# ##### Use the right arrow key if you want to move the cursor to the end.

# %%
1. one
2. two
3. three
4. four
5. five
6. six
7. seven
8. eight

# %% [markdown]
# #### #8 - Create an Alarm Fr When Code Finishes

# %%
# !pip install jupyternotify
# Out:
# ...
#   Created wheel for jupyternotify: filename=jupyternotify-0.1.15-py3-none-any.whl size=8741 sha256=45353b1772fbfe43165684d9d6eaa373fd5db4ff1f2e28f65c7bc655746c501c
#   Stored in directory: c:\users\heart\appdata\local\pip\cache\wheels\db\f4\43\06c94fe0f5bacf0029ea8ebb8d080f372b97661740be7b3d74
# Successfully built jupyternotify
# ...

# %%
# %load_ext jupyternotify

# %%
# %%notify
# cap = 100
# rate = 1.1
# year = 7
# final = cap * rate **year
# print(final)
# Out:
# 194.87171000000012

# %%
# %%notify
# import time
# import random
#
# r = random.randint(30, 60)
# time.sleep(r)
#
# print("Cell finished executed")
# Out:
# Cell finished executed

# %%
# If a piece of code takes long time to run, you can add code to have Python tell you when it is finsihed running.
import winsound
duration = 1000 # milliseconds
freq = 400 # HZ
winsound.Beep(freq, duration)

# %%
##### For Mac, use below code:
import os
os.system('say "Your program has finished"')

# %% [markdown]
# #### #9 - Add Jupyter Notebook Extensions for Increased productivity
# ##### https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html
# ##### Some of the useful ones for me are collapsible headings, codefolding, scratchpad and spellchecker.

# %%
# !pip install jupyter_contrib_nbextensions
# Out:
# ...
#   Created wheel for jupyter-latex-envs: filename=jupyter_latex_envs-1.4.6-py2.py3-none-any.whl size=963413 sha256=916c139467ffb2574516b3297b4d9770b71917399e97dce984506fea38b09a1a
#   Stored in directory: c:\users\heart\appdata\local\pip\cache\wheels\f7\b5\78\f5b899dd8fc137fe0bfe26b382713f6d171c9eac2fb1fa091f
# Successfully built jupyter-latex-envs
# ...

# %% [markdown]
# #### #10 Show Method Documentation
# ##### Shift + Tab

# %%
import pandas as pd
pd.read_csv()

# %% [markdown]
# #### 11 - Extend Number of Columns and Rows Shown in Pandas
# ##### There are a limited number of rows and columns that are shown in a pandas table,
# ##### but you can customize the limit to your liking.
# ##### Here, I’ve set the max output of rows and columns to 200.

# %%
import pandas as pd
df1 = pd.read_csv("airline_safety.csv")

# %%
df1.head()
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# 2                      0                 0                1
# 3                      1                64                5
# 4                      0                 0                2
#
#    fatal_accidents_00_14  fatalities_00_14  pct_incidents
# 0                      0                 0       6.23e-09
# 1                      1                88       6.35e-08
# ...

# %%
pd.options.display.max_rows # Check max rows to display
# Out:
# 200

# %%
pd.options.display.max_rows = 360

# %%
pd.options.display.max_columns # Check max columns to display
# Out:
# 200

# %%
pd.options.display.max_columns = 360

# %%
pd.options.display.max_colwidth
# Out:
# 50

# %%
pd.options.display.max_colwidth = 120

# %%
pd.options.display.precision
# Out:
# 6

# %%
pd.options.display.precision = 2

# %%
import pandas as pd
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

# %% [markdown]
# #### # 12 - Bold or Color our Outputs to make it Stand out

# %%
from IPython.display import Markdown, display
def printmd(string):
    display(Markdown(string))

    printmd("**bold text")

# %%
##### Or you can add color using html:
from IPython.display import Markdown, display
def printmd(string, color=None):
    colorstr = "<span style='color:{}'>{}</span>".format(color, string)
    display(Markdown(colorstr))

printmd("**bold and blue**", color="blue")
# Out:
# <span style='color:blue'>**bold and blue**</span>

# %%
a = "Try this bold and blue"
print(a)
# Out:
# Try this bold and blue

# %% [markdown]
# #### # 13 - Organize and Document your analysis
# ##### '#' symbol samples

# %% [markdown]
# # Level 1 <br/>
# ## Level 2 <br/>
# ### Level 3 <br/>
# #### Level 4 <br/>
# ##### Level 5 <br/>
# normal <br/>

# %% [markdown]
# #### #14 - Shortcuts in Jupyter Notebooks

# %%
# dd
# Type dd this cell will be deleted

# %%
# b
# To create cells below

# %%
# a
# To create cells above

# %%
# m
# Switch to Markdown

# %%
# y
# Switch from Markdown to Code

# %%
# Ctrl + Enter 
# Run the cell and stay on the cell
a = 5
print(a)
# Out:
# 5

# %%
# Shift + Enter
# Run the cell and jump to next cell
a = 5
print(a)
# Out:
# 5

# %%
b = 7
print(a * b)

# %% [markdown]
# #### 15 - Create a slideshow out of notebook

# %% [markdown]
# view --> cell toolbar --> slideshow

# %% [markdown]
# Slides - Main option <br/>
# Sub-slide - fill full screen >br/>
# Fragments - underneath slide/sub-slide add additional information <br/>
# Skip - dont't include cell <br/>
# Notes - don't include cell <br>
